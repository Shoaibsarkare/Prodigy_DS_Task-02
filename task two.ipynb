# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
gender_submission_data = pd.read_csv(r"C:\Users\Wealth\Downloads\gender_submission.csv")

# %%
train_data = pd.read_csv(r"C:\Users\Wealth\Downloads\train.csv")

# %%
test_data = pd.read_csv(r"C:\Users\Wealth\Downloads\test.csv")

# %%
test_data.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
gender_submission_data.columns
# Out:
# Index(['PassengerId', 'Survived'], dtype='object')

# %%
test_data
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
train_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
gender_submission_data
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
test_data.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
gender_submission_data.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
train_data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
train_data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
train_data.Survived.value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
plt=train_data.Pclass.value_counts().sort_index().plot(kind='bar',title ='')
plt.set_xlabel('Pclass')
plt.set_ylabel('Survival Probability')
train_data[['Pclass','Survived']].groupby('Pclass').count()
train_data[['Pclass','Survived']].groupby('Pclass').sum()
plt=train_data[['Pclass','Survived']].groupby('Pclass').mean().Survived.plot(kind='bar')
plt.set_xlabel('Pclass')
plt.set_xlabel('Survival Probability')
# Out:
# Text(0.5, 0, 'Survival Probability')

# %%
plt.set_xlabel('Sex')
plt.set_ylabel('Survival Probability')
plt = train_data.Embarked.value_counts().sort_index().plot(kind = 'bar' , color = 'salmon')
plt.set_xlabel('Embarked')
plt.set_ylabel('Passenger Count')
plt= train_data[['Embarked', 'Survived']].groupby('Embarked').mean().Survived.plot(kind = 'bar' , color = 'salmon')
plt.set_xlabel('Embarked')
plt.set_ylabel('Survival Probability')
# Out:
# Text(0, 0.5, 'Survival Probability')

# %%
colors = sns.color_palette('muted')
plt = train_data.SibSp.value_counts().sort_index().plot(kind = 'bar' , color=colors[4])
plt.set_xlabel('SibSp')
plt.set_ylabel('Passenger Count')
plt = train_data[['SibSp','Survived']].groupby('SibSp').mean().Survived.plot(kind='bar')
plt.set_xlabel('SibSp')
plt.set_ylabel('Survival Probability')
# Out:
# Text(0, 0.5, 'Survival Probability')

# %%
colors = sns.color_palette('muted')
plt=train_data.Parch.value_counts().sort_index().plot(kind='bar' , color=colors[5])
plt.set_xlabel('Parch')
plt.set_ylabel('Passenger count')
# Out:
# Text(0, 0.5, 'Passenger count')

# %%
plt=train_data.Survived.value_counts().plot(kind='bar')
plt.set_xlabel('Survived or not')
plt.set_ylabel('Passenger Count')
plt=train_data.Pclass.value_counts().sort_index().plot(kind='bar',title=' ')
plt.set_xlabel('Pclass')
plt.set_ylabel('Survival Probability')
train_data[['Pclass','Survived']].groupby('Pclass').count()
train_data[['Pclass','Survived']].groupby('Pclass').sum()
plt=train_data[['Pclass','Survived']].groupby('Pclass').mean().Survived.plot(kind='bar')
plt.set_xlabel('Pclass')
plt.set_ylabel('survival Probability')
plt=train_data.Sex.value_counts().sort_index().plot(kind='bar')
plt.set_xlabel('Sex')
plt.set_ylabel('Passenger Count')
plt=train_data[['Sex','Survived']].groupby('Sex').mean().Survived.plot(kind='bar')
plt.set_xlabel('Sex')
plt.set_ylabel('Survival Probablity')
plt=train_data.Embarked.value_counts().sort_index().plot(kind='bar')
plt.set_xlabel('Embarked')
plt.set_ylabel('Passenger count')
plt=train_data[['Embarked', 'Survived']].groupby('Embarked').mean().Survived.plot(kind='bar')
plt.set_xlabel('Embarked')
plt.set_ylabel('Survival Probability')
plt=train_data.SibSp.value_counts().sort_index().plot(kind='bar')
plt.set_xlabel('SibSp')
plt.set_ylabel('Passenger Count')
plt=train_data[['SibSp','Survived']].groupby('SibSp').mean().Survived.plot(kind='bar')
plt.set_xlabel('SibSp')
plt.set_ylabel('Survival Probability')
plt=train_data.Parch.value_counts().sort_index().plot(kind='bar')
plt.set_xlabel('Parch')
plt.set_ylabel('Passenger count')
plt=train_data[['Parch','Survived']].groupby('Parch').mean().Survived.plot(kind='bar')
plt.set_xlabel('Parch')
plt.set_ylabel('Survival Probability')
sns.factorplot('Pclass', col='Embarked',data=train_data, kind='count')
sns.factorplot('Sex', col='Pclass', data=train_data, kind='count')
sns.factorplot('Sex', col='Embarked', data=train_data, kind='count')
train_data.head()
train_data['FamiySize']=train_data['SibSp']+train_data['Parch'] + 1
train_data.head()
train_data=train_data.drop(columns=['Ticket','PassengerId','Cabin'])
train_data.head()
train_data['Sex']=train_data['Sex'].map({'male':0,'female':1})
train_data['Embarked']=train_data['Embarked'].map({'C':0,'Q':1,'S':2})
train_data.head()
train_data['Title']=train_data.Name.str.extract('([A-Za-z]+)\.',expand=False)
train_data=train_data.drop(columns='Name')
train_data.Title.unique()
train_data.Title.value_counts().plot(kind='bar')
train_data['Title']=train_data['Title'].replace(['Dr','Rev','Col','Major','Countess','Sir','Jonkheer','Lady','Capt','Don',],'Others')
train_data['Title']=train_data['Title'].replace('Ms','Miss')
train_data['Title']=train_data['Title'].replace('Mlle','Miss')
train_data['Title']=train_data['Title'].replace('Mme','Mrs')
train_data['Title']=train_data['Title'].replace('Master','Mr')
plt=train_data.Title.value_counts().sort_index().plot(kind='bar')
plt.set_xlabel('Title')
plt.set_ylabel('Passenger count')
plt = train_data[['Title', 'Survived']].groupby('Title').mean().Survived.plot(kind='bar')
plt.set_xlabel('Title')
plt.set_ylabel('Survival Probability')
train_data['Title'] = train_data['Title'].map({'Master':0, 'Miss':1, 'Mr':2, 'Mrs':3, 'Others':4})
corr_matrix = train_data.corr()
import matplotlib.pyplot as plt
plt.figure(figsize=(9, 8))
sns.heatmap(data = corr_matrix,cmap='BrBG', annot=True, linewidths=0.2)
train_data.isnull().sum()
train_data['Embarked'] = train_data['Embarked'].fillna(2)
train_data.head
age_median_train = train_data.Age.median()
train_data.Age = train_data.Age.fillna(age_median_train)
print(age_median_train)
train_data.isnull().sum()
train_data.head()
from sklearn.utils import shuffle
train_data = shuffle(train_data)
x_train = train_data.drop(columns='Survived')
y_train = train_data[['Survived']]
x_train.shape
train_data=train_data.drop(columns='Sex')
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
x_training, x_valid, y_training, y_valid = train_test_split(x_train, y_train, test_size=0.2, random_state=100)
logreg_clf = LogisticRegression()
logreg_clf.fit(x_training,y_training)
prediction=logreg_clf.predict(x_valid)
from sklearn.metrics import accuracy_score
accuracy_score(y_valid,prediction)
from sklearn.metrics import confusion_matrix
confusion=confusion_matrix(y_valid,prediction,labels=[1,0])
print(confusion)
from sklearn.metrics import classification_report
report= classification_report(y_valid, prediction)
print(report)
# Out:
# <>:47: SyntaxWarning: invalid escape sequence '\.'
# <>:47: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\Wealth\AppData\Local\Temp\ipykernel_21160\1152309541.py:47: SyntaxWarning: invalid escape sequence '\.'
#   train_data['Title']=train_data.Name.str.extract('([A-Za-z]+)\.',expand=False)
# C:\Users\Wealth\AppData\Local\Temp\ipykernel_21160\1152309541.py:47: SyntaxWarning: invalid escape sequence '\.'
#   train_data['Title']=train_data.Name.str.extract('([A-Za-z]+)\.',expand=False)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 36
#      34 plt.set_xlabel('Parch')
#      35 plt.set_ylabel('Survival Probability')
# ---> 36 sns.factorplot('Pclass', col='Embarked',data=train_data, kind='count')
#      37 sns.factorplot('Sex', col='Pclass', data=train_data, kind='count')
#      38 sns.factorplot('Sex', col='Embarked', data=train_data, kind='count')
# ...

# %%
# Display basic information and statistics
print("Train Dataset Info")
print(train_data.info())
print("\nTrain Dataset Description")
print(train_data.describe())

print("\nTest Dataset Info")
print(test_data.info())
print("\nTest Dataset Description")
print(test_data.describe())

print("\nGender Submission Dataset Info")
print(gender_submission_data.info())
print("\nGender Submission Dataset Description")
print(gender_submission_data.describe())

# Check for missing values
print("\nMissing Values in Train Dataset")
print(train_data.isnull().sum())

print("\nMissing Values in Test Dataset")
print(test_data.isnull().sum())

# Set seaborn style
sns.set(style="whitegrid")

# Visualize distributions and relationships between key features
plt.figure(figsize=(10, 6))
sns.histplot(train_data['Age'].dropna(), kde=True, color='skyblue', bins=30)
plt.title('Age Distribution in Train Dataset', fontsize=16)
plt.xlabel('Age', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.show()

plt.figure(figsize=(10, 6))
sns.countplot(x='Survived', data=train_data, palette='Set2')
plt.title('Survival Count in Train Dataset', fontsize=16)
plt.xlabel('Survived', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.show()

plt.figure(figsize=(10, 6))
sns.countplot(x='Pclass', hue='Survived', data=train_data, palette='Set1')
plt.title('Survival Count by Passenger Class in Train Dataset', fontsize=16)
plt.xlabel('Passenger Class', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.legend(title='Survived', loc='upper right')
plt.show()

plt.figure(figsize=(10, 6))
sns.countplot(x='Sex', hue='Survived', data=train_data, palette='coolwarm')
plt.title('Survival Count by Sex in Train Dataset', fontsize=16)
plt.xlabel('Sex', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.legend(title='Survived', loc='upper right')
plt.show()

plt.figure(figsize=(10, 6))
sns.histplot(train_data['Fare'], kde=True, color='purple', bins=30)
plt.title('Fare Distribution in Train Dataset', fontsize=16)
plt.xlabel('Fare', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.show()

plt.figure(figsize=(10, 6))
sns.boxplot(x='Pclass', y='Age', data=train_data, palette='Pastel1')
plt.title('Age Distribution by Passenger Class in Train Dataset', fontsize=16)
plt.xlabel('Passenger Class', fontsize=14)
plt.ylabel('Age', fontsize=14)
plt.show()

# Creating a heatmap of correlation matrix
plt.figure(figsize=(12, 10))
sns.heatmap(train_data.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Heatmap in Train Dataset', fontsize=16)
plt.show()

# Print first few rows of each dataset
print("\nFirst Few Rows of Train Dataset")
print(train_data.head())

print("\nFirst Few Rows of Test Dataset")
print(test_data.head())

print("\nFirst Few Rows of Gender Submission Dataset")
print(gender_submission_data.head())
# Out:
# Train Dataset Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None
#
# Train Dataset Description
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set seaborn style
sns.set(style="whitegrid")

# Visualize distributions and relationships between key features
plt.figure(figsize=(10, 6))
sns.histplot(train_data['Age'].dropna(), kde=True, color='skyblue', bins=30)
plt.title('Age Distribution in Train Dataset', fontsize=16)
plt.xlabel('Age', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Survived', data=train_data,)
plt.title('Survival Count in Train Dataset', fontsize=16)
plt.xlabel('Survived', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.countplot(x='Pclass', hue='Survived', data=train_data, palette='Set1')
plt.title('Survival Count by Passenger Class in Train Dataset', fontsize=16)
plt.xlabel('Passenger Class', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.legend(title='Survived', loc='upper right')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.countplot(x='Sex', hue='Survived', data=train_data, palette='coolwarm')
plt.title('Survival Count by Sex in Train Dataset', fontsize=16)
plt.xlabel('Sex', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.legend(title='Survived', loc='upper right')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.histplot(train_data['Fare'], kde=True, color='purple', bins=30)
plt.title('Fare Distribution in Train Dataset', fontsize=16)
plt.xlabel('Fare', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.boxplot(hue='Pclass', y='Age', data=train_data, palette='Pastel1', legend=False)
plt.title('Age Distribution by Passenger Class in Train Dataset', fontsize=16)
plt.xlabel('Passenger Class', fontsize=14)
plt.ylabel('Age', fontsize=14)
plt.show()
